# %% [markdown]
# ---
# # **Day 13 📅**
#
# ---
#
# *Debugging: How to Find and Fix Errors in your code*
#
# ---
#  **Debugging**
#
#  ![image.png](data:image/png;base64,...)
#
# ---

# %% [markdown]
# ---
#
# *Every one gets bugs 🐞*
#
# ---
#
#    * 1. Describe the Problem.
#
# ---
#        def my_function():
#          for i in range(1, 20):
#            if i == 20:
#              print("You got it")
#
# ---
#
#
#       my_function()
#
# ---

# %%
def my_function():
  for i in range(1, 20):
    if i == 20:
      print("You got it")

my_function()

# %% [markdown]
# ---
# *Notice if we go ahead and hit run, you can see that nothing gets printed. 🙃 So whats going on here 🤔*
#
# ---
#  * What is the for loop doing?
#
#  * When is the function meant to print "You got it"?
#
#  * What are your assumptions about i?
#
# ---

# %%
# Describe problem

def my_function():
  for i in range(1, 21):
    if i == 20:
      print("You got it")

my_function()
# Out:
# You got it

# %% [markdown]
# ---
#
#    * 2.Reproduce the Bug 🐞 🐞 🐞
#
# ---
#
#      from random import randint
#      dice_imgs = ["1", "2", "3", "4", "5", "6"]
#      dice_num = randint(1, 6)
#      print(dice_imgs[dice_num])
#
# ---

# %%
from random import randint
dice_imgs = ["1", "2", "3", "4", "5", "6"]
dice_num = randint(1, 6)
print(dice_imgs[dice_num])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-f838a6c7af00> in <cell line: 4>()
#       2 dice_imgs = ["1", "2", "3", "4", "5", "6"]
#       3 dice_num = randint(1, 6)
# ----> 4 print(dice_imgs[dice_num])
#
# IndexError: list index out of range

# %% [markdown]
# ---
# *These types of bugs are really difficult because you might test your code only once or twice, and it looks all fine. it works but then occasionally you get an error.*
#
# ---
# *And the important thing is to reproduce that error.*
#
#    * When does that error actually happen?
#
#    * Try to reproduce the bug yourself and try to notice when it happens
#
#    * And see if you can change the code so that it always produces this error.
#
# ---

# %%
from random import randint
dice_imgs = ["1", "2", "3", "4", "5", "6"]
dice_num = 1
print(dice_imgs[dice_num])
# Out:
# 2

# %%
from random import randint
dice_imgs = ["1", "2", "3", "4", "5", "6"]
dice_num = 6
print(dice_imgs[dice_num])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-637022c9c937> in <cell line: 4>()
#       2 dice_imgs = ["1", "2", "3", "4", "5", "6"]
#       3 dice_num = 6
# ----> 4 print(dice_imgs[dice_num])
#
# IndexError: list index out of range

# %% [markdown]
# ---
# *Now everytime we hit run, you can see we get an error. and now that we've got our error to show up consistently, it's alot easier to dubug because we know that*
#
#       Index error list: list index out of range
#
# ---

# %%
from random import randint
dice_imgs = ["1", "2", "3", "4", "5", "6"]
dice_num = randint(1, 6)
print(dice_imgs[dice_num])
# Out:
# 5

# %% [markdown]
# ---
#   * 3.Play Computer and Evaluate Each Line?
#
# ---

# %%
year = int(input("what's your year of birth?"))
if year > 1980 and year < 1994:
  print(f"You are a millenial.")
elif year > 1994:
  print(f"You are a Gen Z.")
# Out:
# what's your year of birth?1994

# %% [markdown]
# ---
# *So we have our bug right there. Run through the code line-by-line and evaluate each statement.*
#
# ---
#  * So i want you to play computer and figure out what is the problem
#
#  * And then go aheaad and fix the bug.
#
# ---

# %%
year = int(input("what's your year of birth? "))
if year > 1980 and year < 1994:
  print(f"You are a millenial.")
elif year >= 1994:
  print(f"You are a Gen Z.")
# Out:
# what's your year of birth? 1994
# You are a Gen Z.

# %% [markdown]
# ---
# * 4. Fixing Errors and Watching for Red Underlines
#
# ---

# %%
age = input("How old are you?")
if age > 18:
print("You can drive at age {age}.")
# Out:
#   File "<ipython-input-19-8abc4aa4b31f>", line 3
#     print("You can drive at age {age}.")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
age = input("How old are you? ")
if age > 18:
  print("You can drive at age {age}.")
# Out:
# How old are you? 12
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-42454424f186> in <cell line: 2>()
#       1 age = input("How old are you? ")
# ----> 2 if age > 18:
#       3   print("You can drive at age {age}.")
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
age = int(input("How old are you? "))
if age > 18:
  print("You can drive at age {age}.")
# Out:
# How old are you? 21
# You can drive at age {age}.

# %%
age = int(input("How old are you? "))
if age > 18:
  print(f"You can drive at age {age}.")
# Out:
# How old are you? 21
# You can drive at age 21.

# %% [markdown]
# ---
#  * 5. Print is Your Friend
#
# ---

# %%
pages = 0
word_per_page = 0
pages = int(input("Number of pages: "))
word_per_page == int(input("Number of words peer page: "))
total_words = pages * word_per_page
print(total_words)
# Out:
# Number of pages: 45
# Number of words peer page: 250
# 0

# %% [markdown]
# ---
#
# * So what's going on here?
# * How can we debug this?
# ---

# %%
pages = 0
word_per_page = 0
pages = int(input("Number of pages: "))
word_per_page == int(input("Number of words peer page: "))
total_words = pages * word_per_page
print(f"pages = {pages}")
print(f"word_per_page = {word_per_page}")
print(total_words)
# Out:
# Number of pages: 45
# Number of words peer page: 250
# pages = 45
# word_per_page = 0
# 0

# %%
pages = 0
word_per_page = 0
pages = int(input("Number of pages: "))
word_per_page = int(input("Number of words peer page: "))
total_words = pages * word_per_page
print(f"pages = {pages}")
print(f"word_per_page = {word_per_page}")
print(total_words)
# Out:
# Number of pages: 45
# Number of words peer page: 250
# pages = 45
# word_per_page = 250
# 11250

# %% [markdown]
# ---
#
# * 6.Use a Debugger 🦟 🐞 🪳 🐜
# ---
#
#     def mutate(a_list):
#       b_list = []
#       for item in a_list:
#         new_item = item * 2
#       b_list.append(new_item)
#       print(b_list)
#
# ---
#
#
#
#     mutate([1, 2, 3, 5, 8, 13])
# ---

# %%
def mutate(a_list):
  b_list = []
  for item in a_list:
    new_item = item * 2
  b_list.append(new_item) # break point
  print(b_list)

mutate([1, 2, 3, 5, 8, 13])
# Out:
# [26]

# %%
def mutate(a_list):
  b_list = []
  for item in a_list:
    new_item = item * 2
    b_list.append(new_item) # break point
  print(b_list)

mutate([1, 2, 3, 5, 8, 13])
# Out:
# [2, 4, 6, 10, 16, 26]

# %% [markdown]
# ---
#  *    **Final Debugging Tips**
#
# ---
#
# * 7. Take a break
#
# * 8. Ask a Friend
#
# * 9. Run Often
#
# * 10. Ask StackOverflow
#
# ---
#
# *      **Everyone gets bugs 🐛 🐞 🪳**
#
# ---

# %% [markdown]
# ---
# **Instructions - Debug Odd or Even**
#
# ---
#   * Read this code in main.py
#   * Spot the Problem 🐞.
#   * Modify the code to fix the program.
#
# Fix the code so that it works and passes the tests when you submit.
#
# **Hint :**
#
# Review the previous lesson and go through the 10 steps to tackle these debugging problems.
#
#
#
#
# ---

# %%
number = int(input()) # Which number do you want to check?

if number % 2 = 0: # spotted the error.
  print("This is an even number.")
else:
  print("This is an odd number.")
# Out:
#   File "<ipython-input-33-ecf7c562e4b4>", line 3
#     if number % 2 = 0:
#        ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %% [markdown]
# ---
#  * Error line 4 : if number % 2 = 0:
#  * Remember that single "=" is assignment.
#  * Double "==" is checking equality.
#
# ---

# %%
number = int(input()) # Which number do you want to check?

if number % 2 == 0: # fixed the error.
  print("This is an even number.")
else:
  print("This is an odd number.")
# Out:
# 4
# This is an even number.

# %% [markdown]
# ---
# **Instructions - Debugging Leap Year**
#
# ---
#  * Read this code in main.py
#  * Spot the Problems 🐞.
#  * modify the code to fix the program.
#  * No shortcuts - don't copy-paste to replace the code entirely with a working solution.
#
# Fix the code so that it works and when you hit submit it should pass all the tests.
#
#
# ---

# %%
# Which year do you want to check?
year = input() # spotted the error

if year % 4 == 0:
  if year % 100 == 0:
    if year % 400 == 0:
      print("Leap year.")
    else:
      print("Not leap year.")
  else:
    print("Leap year.")
else:
  print("Not leap year.")
# Out:
# 2024
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-dfcf834b4730> in <cell line: 4>()
#       2 year = input()
#       3
# ----> 4 if year % 4 == 0:
#       5   if year % 100 == 0:
#       6     if year % 400 == 0:
#
# TypeError: not all arguments converted during string formatting

# %% [markdown]
# ---
# * TypeError without int() conversion.
#
#
# ---

# %%
# Which year do you want to check?
year = int(input()) # fixed the Error

if year % 4 == 0:
  if year % 100 == 0:
    if year % 400 == 0:
      print("Leap year.")
    else:
      print("Not leap year.")
  else:
    print("Leap year.")
else:
  print("Not leap year.")
# Out:
# 2024
# Leap year.

# %% [markdown]
# ---
#
# **Instructions - Debugging FizzBuzz**
#
# ---
#  * Read this code in main.py
#  * Spot the Problems 🐞.
#  * Modify the code to fix the progeam.
#  * No shortcuts - don't copy-paste to replace the code entirelly with a working solution.
#
# The code needs to print the solution to the FizzBuzz game.
#
# * Your program should print each number from 1 to x where x is the input number.
#
# * However the number is divisible by 3, then instead of printing the number it should print "Fizz".
#
# * When the number is divisible by 5, then instead of printing the number it should print "Buzz".
#
# * And if the number is divisible by both 3 and 5 e.g., 15 then instead of the number it should print "FizzBuzz".
#
# **Hint :**
#
# There is more than one  fix required.
#
# ---

# %%
target = int(input())
for number in range(1, target + 1):
  if number % 3 == 0 or number % 5 == 0: # use and not or
    print("FizzBuzz")
  if number % 3 == 0:  # use elif
    print("Fizz")
  if number % 5 == 0:   # use elif
    print("Buzz")
  else:
    print([number])
# Out:
# 15
# [1]
# [2]
# FizzBuzz
# Fizz
# [3]
# [4]
# FizzBuzz
# Buzz
# FizzBuzz
# Fizz
# [6]
# [7]
# [8]
# FizzBuzz
# Fizz
# [9]
# FizzBuzz
# Buzz
# [11]
# FizzBuzz
# Fizz
# [12]
# [13]
# [14]
# FizzBuzz
# Fizz
# Buzz

# %%
target = int(input())
for number in range(1, target + 1):
  if number % 3 == 0 and number % 5 == 0:
    print("FizzBuzz")
  elif number % 3 == 0:
    print("Fizz")
  elif number % 5 == 0:
    print("Buzz")
  else:
    print([number])
# Out:
# 15
# [1]
# [2]
# Fizz
# [4]
# Buzz
# Fizz
# [7]
# [8]
# Fizz
# Buzz
# [11]
# Fizz
# [13]
# [14]
# FizzBuzz
