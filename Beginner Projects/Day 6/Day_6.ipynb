# %% [markdown]
# ---
# # **Day 6 📅**
#
# ---
# *Functions, Code Blocks and While Loops*
#
# ---
# *Defining and Calling Python Functions*
#
#      Defining Functions
#
#      def my_function():
#        # Do this
#        # Then do this
#        # Finally do this
#
#      Calling Functions
#
#      my_function()
#
# ---
#
# [Built-in Functions](https://docs.python.org/3/library/functions.html)
#
# ---

# %%
print("Hello"); num_char = len("Hello"); print(num_char);
# Out:
# Hello
# 5

# %%
def my_function():
  print("Hello"); print("Bye");

# %%
my_function()
# Out:
# Hello
# Bye

# %% [markdown]
# ---
# *Indentation in Python*
#
# ---
# [PEP 8 : The Python Style Guide 📓](https://peps.python.org/pep-0008/)
#
#
#
# ---

# %% [markdown]
# # 📁 My Function

# %% [markdown]
# * 📄 print - hello
#
# * 📄 print - world

# %% [markdown]
#
#
# ---
#
#
#     Indentation
#
# ---
#
#     def my_function():
#     ....print("Hello")
#     ....print("World")
#
# ---

# %% [markdown]
# # 📁 My function

# %% [markdown]
# 📄 print - hello

# %% [markdown]
# # 📄 print - World

# %% [markdown]
# ---
#
#
#       Indentation
#
# ---
#
#      def my_function():
#      ....print("Hello")
#      print("World")
#
# ---

# %% [markdown]
# ---
#
#
#      Indentation
#
# ---
#      def my_function():
#      ....if sky == "clear":
#      ........print("blue")
#      ....elif sky == "cloudy":
#      ........print("grey")
#      ....print("Hello")
#      print("World")
#
# ---

# %% [markdown]
# ---
# *Spaces Vs. Tabs*
#
# ---
# *Some people using spaces to indent, other people prefer tabs to indent.*
#
# ---
#
# [Spaces Versus. Tabs ⌨](https://www.youtube.com/watch?v=SsoOG6ZeyUI)
#
#
# ---
# ![image.png](data:image/png;base64,...)
#
#
# ---

# %% [markdown]
# ---
# *Indentation Quiz*
#
# ---
# **Question 1:**
#
# *Which version of code will produce an Indentation Error when it is run?*
#
# *NOTE: The • symbol represents a single space.*
#
# ---
#
#     def my_function():
#     print("Hello")
#
# ---
#
# **Question 2:**
#
# *Which version of code will output "This will run"?*
#
# ---
#
#     def my_function():
#         print("This will run")
#     my_function()
#
# ---
# **Question 3:**
#
# *In which version of code, will you see "This will run" printed?*
#
#
# ---
#     def my_function():
#         a = 3
#         if a > 2:
#             print("This will run")
#     my_function()
#
# ---

# %% [markdown]
# ---
# *While Loops*
#
# ---
# *Comparing between for and While loops*
#
# ---
#     For                              While
#
# ---
#
#
#
#     for item in list_of_items:       While something_is_true:
#         # Do something to each item     # Do something repeatedly
#
#     for number in range(a,b):
#         print(number)
#
# ---
#
#     While Loop
#
# ---
#     While something_is_true:
#         # Do this
#         # Then do this
#         # Then do this
#         # until this condition becomes false at which it ends an exits the while loop.
#
# ---

# %%
fruits = ["Apple", "Pear", "Orange"]
for fruit in fruits:
  print(fruit)
# Out:
# Apple
# Pear
# Orange

# %%
for n in range(1, 6):
  print(n)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ---
#     Infinite Loop
#
# ---
#     while 5 > 3:
#         # Do this
#         # Then do this
#         # Then do this
#         # five is always going to be larger than three until the end of time.
#
#
# ---
